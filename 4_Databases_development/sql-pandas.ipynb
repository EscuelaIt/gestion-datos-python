# %%
import pandas as pd

airports = pd.read_csv('data/airports.csv')
airport_freq = pd.read_csv('data/airports-frequencies.csv')
runways = pd.read_csv('data/runways.csv')

# %% [markdown]
# # SELECT, WHERE, DISTINCT, LIMIT

# %%
#select * from airports
airports
# Out:
#            id    ident           type                                name  \
# 0        6523      00A       heliport                   Total Rf Heliport
# 1      323361     00AA  small_airport                Aero B Ranch Airport
# 2        6524     00AK  small_airport                        Lowell Field
# 3        6525     00AL  small_airport                        Epps Airpark
# 4        6526     00AR         closed  Newport Hospital & Clinic Heliport
# ...       ...      ...            ...                                 ...
# 67170   46378  ZZ-0001       heliport                     Sealand Helipad
# 67171  307326  ZZ-0002  small_airport           Glorioso Islands Airstrip
# 67172  346788  ZZ-0003  small_airport               Fainting Goat Airport
# 67173  342102     ZZZW         closed              Scandium City Heliport
# 67174  313629     ZZZZ  small_airport              Satsuma Iōjima Airport
#
#                   latitude_deg           longitude_deg  elevation_ft  \
# ...

# %%
#select * from airports limit 3
airports.head(3)
# Out:
#        id ident           type                  name       latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport  4.007.080.078.125
# 1  323361  00AA  small_airport  Aero B Ranch Airport         38.704.022
# 2    6524  00AK  small_airport          Lowell Field         59.947.733
#
#             longitude_deg  elevation_ft continent iso_country iso_region  \
# 0  -7.493.360.137.939.450          11.0       NaN          US      US-PA
# 1            -101.473.911        3435.0       NaN          US      US-KS
# 2            -151.692.524         450.0       NaN          US      US-AK
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# 0      Bensalem                no      00A       NaN        00A       NaN
# 1         Leoti                no     00AA       NaN       00AA       NaN
# 2  Anchor Point                no     00AK       NaN       00AK       NaN
#
#   wikipedia_link keywords
# 0            NaN      NaN
# 1            NaN      NaN
# ...

# %%
#select id from airports where ident = 'KLAX'
airports[airports.ident == 'KLAX'].id
# Out:
# 33477    3632
# Name: id, dtype: int64

# %%
#select distinct type from airport
airports.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %% [markdown]
# # Select con múltiples condiciones

# %%
#select * from airports where iso_region = 'US-CA' and type = 'seaplane_base'
airports[(airports.iso_region == 'US-CA') & (airports.type == 'seaplane_base')]
# Out:
#            id    ident           type  \
# 1009     7436      0O0  seaplane_base
# 2568     8877     22CA  seaplane_base
# 6438    12298     5CA9  seaplane_base
# 14766   16514      C39  seaplane_base
# 17200   16830     CN20  seaplane_base
# 19703   17157      E20  seaplane_base
# 25586   17613      H77  seaplane_base
# 36264   21444      L11  seaplane_base
# 43640   23479      O06  seaplane_base
# 47941   24384      S74  seaplane_base
# 55985  300312      TWH  seaplane_base
# 60295  342286  US-3338  seaplane_base
# 60413  342600  US-3456  seaplane_base
#
#                                            name            latitude_deg  \
# 1009           San Luis Reservoir Seaplane Base   3.705.830.001.831.050
# 2568             Commodore Center Seaplane Base              37.878.893
# 6438        Konocti  - Clear Lake Seaplane Base              38.977.699
# 14766                 Folsom Lake Seaplane Base   3.870.719.909.667.960
# ...

# %%
#select ident, name, municipality from airports where iso_region = 'US-CA' and type = 'large_airport'
airports[(airports.iso_region == 'US-CA') & (airports.type == 'large_airport')][['ident', 'name', 'municipality']]
# Out:
#       ident                                               name   municipality
# 31684  KACV  California Redwood Coast-Humboldt County Inter...  Arcata/Eureka
# 31834  KBAB                               Beale Air Force Base     Marysville
# 32087  KCMA                    Camarillo International Airport      Camarillo
# 32679  KEDW                             Edwards Air Force Base        Edwards
# 33453  KL45                  Bakersfield International Airport    Bakersfield
# 33477  KLAX                  Los Angeles International Airport    Los Angeles
# 34006  KOAK         Metropolitan Oakland International Airport        Oakland
# 34062  KONT                      Ontario International Airport        Ontario
# 35588  KSAN                    San Diego International Airport      San Diego
# 35628  KSFO                San Francisco International Airport  San Francisco
# 35649  KSJC    Norman Y. Mineta San Jose International Airport       San Jose
# ...

# %% [markdown]
# # Order BY

# %%
#select * from airport_freq where airport_ident = 'KLAX' order by type
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type')
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11971  60774         3632          KLAX   OPS          AF          37.22
# 11965  60768         3632          KLAX  ATIS        ATIS         133.80
# 11969  60772         3632          KLAX  MISC          CG          34.50
# 11970  60773         3632          KLAX  MISC          CG         898.40
# 11966  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11968  60771         3632          KLAX   GND         GND         121.65
# 11963  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11964  60766         3632          KLAX   APP   SOCAL APP         124.30
# 11967  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11972  60775         3632          KLAX   TWR         TWR         119.80
# 11973  60776         3632          KLAX  UNIC      UNICOM         122.95

# %%
#select * from airport_freq where airport_ident = 'KLAX' order by type desc
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type', ascending=False)
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11973  60776         3632          KLAX  UNIC      UNICOM         122.95
# 11972  60775         3632          KLAX   TWR         TWR         119.80
# 11971  60774         3632          KLAX   OPS          AF          37.22
# 11969  60772         3632          KLAX  MISC          CG          34.50
# 11970  60773         3632          KLAX  MISC          CG         898.40
# 11968  60771         3632          KLAX   GND         GND         121.65
# 11967  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11966  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11965  60768         3632          KLAX  ATIS        ATIS         133.80
# 11963  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11964  60766         3632          KLAX   APP   SOCAL APP         124.30

# %% [markdown]
# # IN… NOT IN
#
# Sabemos cómo filtrar por un valor, pero ¿qué pasa con una lista de valores - condición IN? En pandas, el operador .isin () funciona de la misma manera. Para negar cualquier condición, se utiliza ~.

# %%
#select * from airports where type in ('heliport', 'balloonport')
airports[airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident      type                             name  \
# 0        6523      00A  heliport                Total Rf Heliport
# 9      322658     00CN  heliport  Kitchen Creek Helibase Heliport
# 12       6532     00FD  heliport               Ringhaver Heliport
# 15       6535     00GE  heliport                 Caffrey Heliport
# 16       6536     00HI  heliport               Kaupulehu Heliport
# ...       ...      ...       ...                              ...
# 66820  346457  ZA-0250  heliport       Marula Game Lodge Heliport
# 66873  339169     ZGNT  heliport         Shenzhen Nantou Heliport
# 66897  301278      ZIZ  heliport                 Zamzama Heliport
# 67119  345912  ZW-0048  heliport           Chinyike Mine Heliport
# 67170   46378  ZZ-0001  heliport                  Sealand Helipad
#
#                  latitude_deg           longitude_deg  elevation_ft continent  \
# 0           4.007.080.078.125  -7.493.360.137.939.450          11.0       NaN
# ...

# %%
#select * from airports where type not in ('heliport', 'balloonport')
airports[~airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident            type                                name  \
# 1      323361     00AA   small_airport                Aero B Ranch Airport
# 2        6524     00AK   small_airport                        Lowell Field
# 3        6525     00AL   small_airport                        Epps Airpark
# 4        6526     00AR          closed  Newport Hospital & Clinic Heliport
# 5      322127     00AS   small_airport                      Fulton Airport
# ...       ...      ...             ...                                 ...
# 67169   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 67171  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 67172  346788  ZZ-0003   small_airport               Fainting Goat Airport
# 67173  342102     ZZZW          closed              Scandium City Heliport
# 67174  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
# ...

# %% [markdown]
# # GROUP BY, COUNT, ORDER BY

# %%
'''
select iso_country,
       type,
       count(*)
from airports
group by iso_country, type
order by iso_country, type
'''

airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           closed              1
#              heliport            2
# AE           closed              2
#              heliport           79
#              large_airport       4
#                               ...
# ZW           heliport            1
#              large_airport       1
#              medium_airport      8
#              small_airport     131
# ZZ           heliport            1
# Length: 928, dtype: int64

# %% [markdown]
# # HAVING

# %%
'''
select type,
       count(*)
from airports
where iso_country = 'US'
group by type
having count(*) > 1000
order by count(*) desc
'''

(
    airports[airports.iso_country == 'US']
    .groupby('type')
    .filter(lambda g: len(g) > 1000)
    .groupby('type')
    .size()
    .sort_values(ascending=False)
)
# Out:
# type
# small_airport    14251
# heliport          7265
# closed            4160
# dtype: int64

# %%
lst = []
_dict = {}

lst_dct = [{'key': 'value'}, {'name': 'Alvaro'}, {'lastname': 'Martinez'}]
lst_dct
lst_dct[1]['name']
# Out:
# dict_keys(['name'])

# %% [markdown]
# # Funciones de Agregación (MIN, MAX, MEAN)

# %%
runways.columns
# Out:
# Index(['id', 'airport_ref', 'airport_ident', 'length_ft', 'width_ft',
#        'surface', 'lighted', 'closed', 'le_ident', 'le_latitude_deg',
#        'le_longitude_deg', 'le_elevation_ft', 'le_heading_degT',
#        'le_displaced_threshold_ft', 'he_ident', 'he_latitude_deg',
#        'he_longitude_deg', 'he_elevation_ft', 'he_heading_degT',
#        'he_displaced_threshold_ft'],
#       dtype='object')

# %%
#select max(length_ft), min(length_ft), avg(length_ft), median(length_ft) from runways
runways.agg({'length_ft': ['min', 'max', 'mean', 'median']})
# Out:
#             length_ft
# min          0.000000
# max     120000.000000
# mean      3246.695713
# median    2700.000000

# %%
#Transposicion
runways.agg({'length_ft': ['min', 'max', 'mean', 'median']}).T
# Out:
#            min       max         mean  median
# length_ft  0.0  120000.0  3246.695713  2700.0

# %% [markdown]
# # JOIN

# %%
'''
select airport_ident,
       type,
       description,
       frequency_mhz
from airport_freq
inner join airports on airport_freq.airport_ref = airports.id
where airports.ident = 'KLAX'
'''
(
    airport_freq.merge(
        airports[airports.ident == 'KLAX'][['id']],
        left_on='airport_ref', right_on='id',
        how='inner')
    [['airport_ident','type', 'description', 'frequency_mhz']]
)
# Out:
#    airport_ident  type description  frequency_mhz
# 0           KLAX   APP   SOCAL APP          36.07
# 1           KLAX   APP   SOCAL APP         124.30
# 2           KLAX  ATIS        ATIS         133.80
# 3           KLAX   CLD    CLNC DEL         121.40
# 4           KLAX   DEP   SOCAL DEP         124.30
# 5           KLAX   GND         GND         121.65
# 6           KLAX  MISC          CG          34.50
# 7           KLAX  MISC          CG         898.40
# 8           KLAX   OPS          AF          37.22
# 9           KLAX   TWR         TWR         119.80
# 10          KLAX  UNIC      UNICOM         122.95

# %% [markdown]
# # UNION ALL and UNION
#
# Link de Interes:
# * https://codenostra.com/es/cul-es-la-diferencia-entre-union-y-union-all.html#:~:text=Diferencia%3A-,La%20diferencia%20entre%20UNION%20y%20UNION%20ALL%20es%20que%20UNION,UNION%20ALL%20incluir%C3%A1%20registros%20duplicados.&text=Nota%20%3A%20El%20rendimiento%20de%20UNION,adicional%20de%20eliminar%20cualquier%20duplicado.

# %%
'''
select name,
       municipality
from airports
where ident = 'KLAX'

union all

select name,
       municipality
from airports
where ident = 'KLGB'
'''
(
    pd.concat(
        [airports[airports.ident == 'KLAX'][['name', 'municipality']],
         airports[airports.ident == 'KLGB'][['name', 'municipality']]]
    )
)
# Out:
#                                        name municipality
# 33477     Los Angeles International Airport  Los Angeles
# 33503  Long Beach Airport (Daugherty Field)   Long Beach

# %%
'''
select name,
       municipality
from airports
where ident = 'KLAX'

union

select name,
       municipality
from airports
where ident = 'KLGB'
'''

pd.concat([airports[airports.ident == 'KLAX'][['name', 'municipality']], airports[airports.ident == 'KLGB'][['name', 'municipality']]]).drop_duplicates()

#Aclaración: Al obtener el mismo resultado se observa que no teníamos duplicados asociados.
# Out:
#                                        name municipality
# 33477     Los Angeles International Airport  Los Angeles
# 33503  Long Beach Airport (Daugherty Field)   Long Beach

# %% [markdown]
# # INSERT

# %%
#create table heroes (id integer, name text)
df1 = pd.DataFrame({'id': [1, 2], 'name': ['Harry Potter', 'Ron Weasley']})
df1
# Out:
#    id          name
# 0   1  Harry Potter
# 1   2   Ron Weasley

# %%
#insert into heroes values (3, 'Hermione Granger')
df2 = pd.DataFrame({'id': [3], 'name': ['Hermione Granger']})
df2
# Out:
#    id              name
# 0   3  Hermione Granger

# %%
df3 = pd.concat([df1, df2]).reset_index(drop=True)
df3
# Out:
#    id              name
# 0   1      Harry Potter
# 1   2       Ron Weasley
# 2   3  Hermione Granger

# %% [markdown]
# # UPDATE

# %%
#update airports set home_link = 'http://www.lawa.org/welcomelax.aspx' where ident == 'KLAX'
airports.loc[airports['ident'] == 'KLAX', 'home_link'] = 'http://www.lawa.org/welcomelax.aspx'
airports[airports['home_link'] == 'http://www.lawa.org/welcomelax.aspx']
# Out:
#          id ident           type                               name  \
# 33477  3632  KLAX  large_airport  Los Angeles International Airport
#
#       latitude_deg longitude_deg  elevation_ft continent iso_country  \
# 33477   33.942.501  -118.407.997         125.0       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 33477      US-CA  Los Angeles               yes     KLAX       LAX        LAX
#
#                                  home_link  \
# 33477  http://www.lawa.org/welcomelax.aspx
#
#                                           wikipedia_link keywords
# 33477  https://en.wikipedia.org/wiki/Los_Angeles_Inte...      NaN

# %% [markdown]
# # DELETE

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip']})
df
# Out:
#        name        toy
# 0    Alfred        NaN
# 1    Batman  Batmobile
# 2  Catwoman   Bullwhip

# %%
df.dropna()
# Out:
#        name        toy
# 1    Batman  Batmobile
# 2  Catwoman   Bullwhip

# %%
df.dropna(axis='columns')
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman
